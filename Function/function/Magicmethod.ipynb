# %% [markdown]
# user difine data type :
# our class name is fraction

# %%
l = [1,2,3,4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
class fraction :
    def __init__(self ,num, deno):
        self.num = num
        self.deno = deno
    def __str__(self):
        return '{}/{}'.format(self.num,self.deno)
    def __add__(self,other):
        new_num = self.num*other.deno + other.num*self.deno
        new_deno = self.deno*other.deno
        return '{}/{}'.format(new_num,new_deno)
    def __sub__(self,other):
        new_num = self.num*other.deno - other.num*self.deno
        new_deno = self.deno*other.deno
        return '{}/{}'.format(new_num,new_deno)
    def __mul__(self,other):
        new_num = self.num*other.num
        new_deno = self.deno*other.deno
        return '{}/{}'.format(new_num,new_deno)
    def __truediv__(self,other):
        new_num = self.num*other.deno
        new_deno = self.deno*other.num
        return '{}/{}'.format(new_num,new_deno)

# %%
obj1 = fraction(1,2)
obj2 = fraction(2,3)

# %%
print(obj1)
# Out:
# 1/2

# %%
print(obj1 + obj2)
# Out:
# 7/6

# %%
print(obj1 - obj2)
# Out:
# -1/6

# %%
print(obj1 * obj2)
# Out:
# 2/6

# %%
print(obj1 / obj2)
# Out:
# 3/4

# %%
class student:
    def __init__(self , Name , Marks):
        self.Name = Name
        self.Marks = Marks
        self.total_marks = sum(Marks)
    def __str__(self):
        return f"Student:{self.name}|Total Marks:{self.total_marks}"
        
    def __gt__(self):

# %%
rows = 5
for i in range(1 , rows + 1):
    for j in range(i):
        print("*",end = " ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n = int(input("enter number : "))
f = 1
for i in range(1,n+1):
    f *= i
print("fact =", f)
# Out:
# fact = 120

# %%
def is_prime(n):
    for i in range(2,n):
        if n%i == 0:
            print(f'{n} is not prime number !')
            break
        else:
            print(f'{n} is prime number !')
            break

# %%
n = int(input("Enter a number :"))
if n <= 1:
    print("Not Prime")
else:
    for i in range(2,n):
        if n % i == 0:
            print("Not prime")
            break
    else:
        print("prime number")
# Out:
# Not prime

# %%
n = int(input("Enter a number :"))
if n <=1 :
    print("not prime")
else:
    for i in range(2,n):
        if n % i == 0:
            print("not prime")
            break
    else:
        print("prime")
# Out:
# not prime

# %%
l = [1,2,2,3,4,4,5]
new = []
for i in l:
    if i not in new:
        new.append(i)

print(new)
# Out:
# [1, 2, 3, 4, 5]

# %%
l = [1,2,2,3,4,4,5]
s = set(l)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
l = [10,20,4,45,99]
maximum = max(l)
second_max = 0
for i in l:
    if i > second_max and i < maximum:
        second_max = i
print(second_max)
# Out:
# 45

# %%
l = [10,20,4,45,99]
l.remove(max(l))
print("second_max : " , max(l))
# Out:
# second_max :  45

# %%
l = [1,2,3,4,5]
rev = []
for i in l:
    rev = [i] + rev
print(rev)
# Out:
# [5, 4, 3, 2, 1]

# %%
s = "programming"
dict = {}
for i in s:
    if i in dict:
        dict[i] = dict[i] + 1
    else:
        dict[i] = 1
print(dict)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
dict = {'harry':85,'ron':75,'hermione':95}
d = {}
for name , marks in i.items():
    if marks > 90  :
        print("d[name],marks")

# %%
class Atm:
    def __init__(self):
        print("Welcome! Please Create Your Account First.")
        self.username = input("Set your New Username: ")
        self.password = input("Set your New Password: ")
        self.balance = 0
        print("Account Created Successfully! \n")
        self.selection()

    def selection(self):

        print('-' * 30)
        choice = input("""
        1. deposit
        2. check
        3. withdraw
        4. exit
        """)
        print('-' * 30)

        if choice == '1':
            self.deposit()
        elif choice == '2':
            self.check()
        elif choice == '3':
            self.withdraw()
        elif choice == '4':
            print('Thanks for Visiting us ! ')
            exit()
        else :
            print('Please Enter the number between 1 to 4 ')
            self.selection()

    def deposit(self):
        username = input("Enter Your username : ")
        password = input('Enter your password  : ')
        if self.username == username and self.password == password:
            amount = float(input('Enter your amount : '))
            self.balance += amount
            print('Your Balance is Succesfully Updated')
            print(f'Our Total balance is {self.balance}')
            self.selection()
        else :
            if username != self.username :
                print('username and password is invaild !')
                try_again = input('Enter y/n : ')
                if try_again == 'y':
                    self.deposit()
                elif try_again == 'n':
                    exit()
                else :
                    print('please enter the y/n words only')
            elif password != self.password:
                print('your password is invaild !')
                self.selection()


    def check(self):
        username = input("Enter Your username : ")
        password = input('Enter your password  : ')
        if self.username == username and self.password == password:
            if self.balance == 0 :
                print("Your bank balance is zero ! (Gareeb) ")
                self.selection()
            else:
                print(f'Total balance is {self.balance}')
                self.selection()
        else :
            if username != self.username :
                print('username and password is invaild !')
                try_again = input('Enter y/n : ')
                if try_again == 'y':
                    self.check()
                elif try_again == 'n':
                    exit()
                else :
                    print('please enter the y/n words only')
            elif password != self.password:
                print('your password is invaild !')
                self.selection()

    def withdraw(self):
        username = input("Enter Your username : ")
        password = input('Enter your password  : ')
        if self.username == username and self.password == password:
            if self.balance == 0 :
                print("Your bank balance is zero ! (Gareeb) ")
                self.selection()
            else:
                withdrawl_amount = float(input("Enter Your Withdrawl Amount : "))
                if withdrawl_amount > self.balance :
                    print('Bro Overdraft facitly is not available')
                    self.withdraw()
                else :
                    self.balance -= withdrawl_amount
                    print('Our Withdraw is Successful !')
                    print(f'Our Withdraw amount is {withdrawl_amount}')
                    self.selection()
        else :
            if username != self.username :
                print('username and password is invaild !')
                try_again = input('Enter y/n : ')
                if try_again == 'y':
                    self.withdraw()
                elif try_again == 'n':
                    exit()
                else :
                    print('please enter the y/n words only')
            elif password != self.password:
                print('your password is invaild !')
                self.selection()
if __name__ == "__main__":
    my_atm = Atm()
Welcome! Please Create Your Account First.
Account Created Successfully! 

------------------------------
------------------------------
Your Balance is Succesfully Updated
Our Total balance is 45000.0
------------------------------
------------------------------
Our Withdraw is Successful !
Our Withdraw amount is 12000.0
------------------------------
------------------------------
Total balance is 33000.0
------------------------------
------------------------------
Thanks for Visiting us !

# %%
l = [1,2,3]
print(l)
# Out:
# [1, 2, 3]
