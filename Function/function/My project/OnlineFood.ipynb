# %%
class ZomatoSystem:
    def __init__(self):
        # Dummy database: {username: password}
        self.users = {"rahul": "1234", "priya": "pass789"}
        self.menu = {
            "Pizza": 299,
            "Burger": 99,
            "Pasta": 150,
            "Coke": 50
        }
        self.is_logged_in = False

    def login(self):
        print("--- Welcome to Zomato ---")
        username = input("Enter Username: ")
        password = input("Enter Password: ")

        if username in self.users and self.users[username] == password:
            print(f"\nLogin Successful! Welcome, {username}.")
            self.is_logged_in = True
        else:
            print("\nInvalid Credentials. Please try again.")
            self.is_logged_in = False

    def show_menu(self):
        print("\n--- Menu Card ---")
        for item, price in self.menu.items():
            print(f"{item}: ₹{price}")

    def place_order(self):
        if not self.is_logged_in:
            print("Please login first!")
            return

        self.show_menu()
        order = input("\nWhat would you like to eat? (Enter name): ").title()

        if order in self.menu:
            qty = int(input(f"How many {order}s do you want? "))
            total = self.menu[order] * qty
            print(f"\n--- Order Summary ---")
            print(f"Item: {order}\nQuantity: {qty}\nTotal Bill: ₹{total}")
            print("Order Placed! Your food is on the way. 🛵")
        else:
            print("Sorry, this item is not available.")

# --- Execution ---
app = ZomatoSystem()
app.login()

if app.is_logged_in:
    app.place_order()
# Out:
# --- Welcome to Zomato ---
#
# Invalid Credentials. Please try again.

# %%
class Zomato:
    def __init__(self):
        self.username = ""
        self.password = ""
        self.is_logged_in = False
        
        
        self.menu = {
            "Pizza":150,
            "Burger":100,
            "Pasta":80,
            "Lemon Juice":30,
            "Cold coffee":70,
            "Ice Cream":30,
            "Cake":200
        }

    def signup(self):
        print('---create your account---')
        self.username = input("set your username :")
        self.password = input("set your password :")
        print("Your account has been created successfully")

    def login(self):
        print('---Welcome to zomato---')
        u_name = input('Enter your Name : ')
        u_pwd = input('Enter your Password : ')

        if u_name == self.username and u_pwd == self.password and self.username != "":
            print(f"\nLogin successful,{u_name}")
            self.is_logged_in = True

        else:
            print(f"\nInavalid Please try again.")
            self.is_logged_in = False

                
    def show_menu(self):
        print('---Menu Card---')
        for item,price in self.menu.items():
            print(f'{item}: Rs:{price}')

    def place_order(self):
        if not self.is_logged_in:
            
            print("please login frist!")
            return
            
        self.show_menu()
        order = input("what you want to order : ").title() # isse upper or lower case dono same considered ho jate hai

        if order in self.menu:
            Qty = int(input('How many {order} do you want'))
            total = self.menu[order] * Qty

            print('---Bill Amount--- ')
            print(f'Item :{order}\nQuantity:{Qty}\nTotal Amount:{total}')
            print('order placed! your order is on the way')

        else:
            print('sorry,this item is not available')


app = Zomato()

app.signup()

app.login()

if app.is_logged_in:
    app.place_order()
# Out:
# ---create your account---
# Your account has been created successfully
# ---Welcome to zomato---
#
# Login successful,shriya
# ---Menu Card---
# Pizza: Rs:150
# Burger: Rs:100
# Pasta: Rs:80
# Lemon Juice: Rs:30
# Cold coffee: Rs:70
# Ice Cream: Rs:30
# Cake: Rs:200
# ---Bill Amount---
# Item :Pizza
# Quantity:2
# Total Amount:300
# order placed! your order is on the way
